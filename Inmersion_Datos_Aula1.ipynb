# %% [markdown]
# <a href="https://colab.research.google.com/github/nestormarlier/alura-latam/blob/main/Inmersion_Datos_Aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Shape (Filas, Columnas)

# %%
import pandas as pd
inmuebles = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Clase1/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# 3    $ 890.000.000
# 4    $ 970.000.000

# %% [markdown]
# Shape (Filas, Columnas)

# %%
inmuebles.shape
# Out:
# (9520, 8)

# %%
inmuebles.columns
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %% [markdown]
# Modificar el nombre de la columna a través de un diccionario

# %%
columnas = {'Baños':'Banos','Área':'Area'}
inmuebles = inmuebles.rename(columns=columnas)

# %% [markdown]
# Generar una muestra de 10 registros

# %%
inmuebles.sample(10)
# Out:
#              Tipo                             Descripcion  Habitaciones  \
# 6087  Apartamento    Apartamento en venta en Gran America             2
# 7838  Apartamento       Apartamento en venta en Chapinero             3
# 6941         Casa  Casa en venta en Bellavista Occidental             9
# 2612         Casa               Casa en venta en Fontibón             3
# 5244  Apartamento     Apartamento en venta en Chico Norte             1
# 8615  Apartamento        Apartamento en venta en Cedritos             2
# 4142         Casa             Casa en venta en Capellania             6
# 464          Casa             Casa en venta en Costa Azul             5
# 8408  Apartamento         Apartamento en venta en Kennedy             2
# 762   Apartamento        Apartamento en venta en Castilla             3
#
#       Banos  Area                 Barrio                                 UPZ  \
# 6087      2    35           Gran America                      Quinta Paredes
# 7838      2   110              Chapinero  CHAPINERO: Pardo Rubio + Chapinero
# 6941      5   456  Bellavista Occidental                          Las Ferias
# 2612      3   133               Fontibón                            Fontibón
# 5244      1    42            Chico Norte  CHAPINERO: Chicó Lago + El Refugio
# 8615      2    63               Cedritos                             Usaquén
# 4142      4   240             Capellania                             Modelia
# 464       3    96             Costa Azul                                Suba
# 8408      1    41                Kennedy                     Kennedy Central
# 762       2    70               Castilla         KENNEDY: Castilla + Bavaria
#
#               Valor
# 6087  $ 250.000.000
# 7838  $ 730.000.000
# 6941  $ 980.000.000
# 2612  $ 710.000.000
# 5244  $ 425.000.000
# 8615  $ 330.000.000
# 4142  $ 880.000.000
# 464   $ 250.000.000
# 8408  $ 128.000.000
# 762   $ 310.000.000

# %% [markdown]
# Información del dataframe, la columna UPZ es la única que tiene valores en null

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# iloc[número] Muestra el registro 300

# %% [markdown]
# Seleccionamos un registro en específico

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %% [markdown]
# Seleccionamos un rango de registros

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles ['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %% [markdown]
# Tipo de dato (type)

# %%
type(inmuebles ['Valor'][300:305])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Promedio del Área de inmuebles en Bogotá

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Filtramos los registros con nombre de Barrio "Chico Reservado", nos genera un dataframe por registro. Verdadero si es "Chico Reservado" y falso si no lo es.

# %%
inmuebles.Barrio == 'Chico Reservado'
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %% [markdown]
# Sumamos la cantidad de propiedades que se encuentran en el barrio "Chico Reservado"

# %%
sum(inmuebles.Barrio=='Chico Reservado')
# Out:
# 225

# %% [markdown]
# Verificamos el tipo de dato que es inmuebles_chico

# %%
inmuebles_chico = inmuebles.Barrio == 'Chico Reservado'
type(inmuebles_chico)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Genero un dataframe chico_reservado con los registros donde la propiedad se encuentre en el barrio filtrado anteriormente

# %%
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# 2         3   144  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 39        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 72        1    64  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 126       4   150  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 143       4   104  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# ...     ...   ...              ...                                 ...
# 9299      3   148  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9335      3   176  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9341      3   118  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9472      1    49  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
# 9506      4   390  Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#                 Valor
# 2     $ 1.120.000.000
# 39      $ 495.000.000
# 72      $ 495.000.000
# 126   $ 1.300.000.000
# 143   $ 1.100.000.000
# ...               ...
# 9299    $ 780.000.000
# 9335    $ 850.000.000
# 9341    $ 700.000.000
# 9472    $ 200.000.000
# 9506  $ 3.200.000.000
#
# [225 rows x 8 columns]

# %% [markdown]
# Sacamos el promedio del Área de chico_reservado. mean

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %% [markdown]
# Comparamos el promedio del área "Chico Reservado" con el promedio del área del todos los inmuebles

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %% [markdown]
# Cantidad de barrios de nuestro dataset

# %%
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %% [markdown]
# Propiedades por Barrio

# %%
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %% [markdown]
# Cantidad de UPZ (Unidad de planemiento zonal)

# %%
(inmuebles.UPZ.value_counts())
# Out:
# Usaquén                                  1681
# CHAPINERO: Pardo Rubio + Chapinero       1274
# USAQUÉN: Country Club + Santa Bárbara     771
# Bosa Central                              591
# Kennedy Central                           589
#                                          ...
# Localidad Usme resto                        2
# Las Cruces                                  2
# La Macarena                                 1
# Fontibón San Pablo                          1
# Zona Franca                                 1
# Name: UPZ, Length: 63, dtype: int64

# %% [markdown]
# Matplotlib

# %%
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Barrios TOP 10 con más inmuebles

# %%
inmuebles_barrio.head(10).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Promedio de Área de todo los inmuebles en los barrios en el Dataset. El Top 10.

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# La columna valor es "object" alfanumérica. Buscamos el valor del primer inmueble en la posición 0 (cero) y vemos que está ente ''

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %% [markdown]
# Vemos el tipo de dato, que es String

# %%
type(inmuebles.Valor[0])
# Out:
# str

# %% [markdown]
# Separamos del primer registro el $ del número a traves de la funcion Split, que usara como separador el espacio en blanco " ".

# %%
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %% [markdown]
# Debo separarlo en todo el dataset

# %%
inmuebles.Valor.str.split()
# Out:
# 0         [$, 360.000.000]
# 1         [$, 670.000.000]
# 2       [$, 1.120.000.000]
# 3         [$, 890.000.000]
# 4         [$, 970.000.000]
#                ...
# 9515      [$, 290.000.000]
# 9516      [$, 670.000.000]
# 9517      [$, 900.000.000]
# 9518      [$, 335.000.000]
# 9519      [$, 144.990.000]
# Name: Valor, Length: 9520, dtype: object

# %% [markdown]
# Genero un dataframe para poder trabajarlo. split(expand=True) para luego colocarlo en mi Dataset y conultarla.

# %%
valor = inmuebles.Valor.str.split(expand=True)
valor
# Out:
#       0              1
# 0     $    360.000.000
# 1     $    670.000.000
# 2     $  1.120.000.000
# 3     $    890.000.000
# 4     $    970.000.000
# ...  ..            ...
# 9515  $    290.000.000
# 9516  $    670.000.000
# 9517  $    900.000.000
# 9518  $    335.000.000
# 9519  $    144.990.000
#
# [9520 rows x 2 columns]

# %% [markdown]
# Vamos a crear una columna "Moneda" en nuestro dataset pero solo el resultado de la primer columna que es '$' y 'Precio' para la otra columna

# %%
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 9127  Apartamento  Apartamento en venta en Chico Reservado             3
# 2441         Casa              Casa en venta en La Calleja             3
# 6215         Casa               Casa en venta en Chapinero             4
#
#       Banos  Area           Barrio                                    UPZ  \
# 9127      2   208  Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 2441      4   410       La Calleja  USAQUÉN: Country Club + Santa Bárbara
# 6215      4   300        Chapinero     CHAPINERO: Pardo Rubio + Chapinero
#
#                 Valor Moneda         Precio
# 9127  $ 1.700.000.000      $  1.700.000.000
# 2441  $ 4.200.000.000      $  4.200.000.000
# 6215  $ 1.800.000.000      $  1.800.000.000

# %% [markdown]
# Nuestra columna 'Precio' sigue figurando como Object, datos alfanuméricos

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %% [markdown]
# Le sacamos los . (puntos) a la columna precios y listo el precio y el barrio de mí dataset

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %% [markdown]
# Precio sigue siendo un bojecto string

# %%
inmuebles.Precio.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 9520 entries, 0 to 9519
# Series name: Precio
# Non-Null Count  Dtype
# --------------  -----
# 9520 non-null   object
# dtypes: object(1)
# memory usage: 74.5+ KB

# %% [markdown]
# Modificamos el tipo de dato de STR a FLOAT, por lo general se transforma a éste para luego maniular los valores. Tambien pasaremos la unidad a millon, eliminando los 0 (ceros). Chequeamos que la columna 'Precio_Millon' paso a ser float64

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Banos          9520 non-null   int64
#  4   Area           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %% [markdown]
# Eliminar posiciones decimales para que sea más facil leer la información.
# pd.set_option('display.precision',2)
# pd.set_option('display.float_format',lambda x: '%.2f' % x)

# %%
pd.set_option('display.precision', 2)
pd.set_option('display.float_format', lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
#        Habitaciones   Banos      Area  Precio_Millon
# count       9520.00 9520.00   9520.00        9520.00
# mean           3.07    2.45    146.66         602.06
# std            2.05    1.26   1731.38         704.60
# min            1.00    0.00      2.00          60.00
# 25%            2.00    2.00     57.00         250.00
# 50%            3.00    2.00     80.00         409.18
# 75%            3.00    3.00    135.00         680.00
# max          110.00    9.00 166243.00       16000.00

# %% [markdown]
# Localizamos el inmueble que tiene 110 habitaciones

# %%
inmuebles.loc[inmuebles.Habitaciones == 110]
# Out:
#      Tipo                Descripcion  Habitaciones  Banos  Area    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000         480.00

# %% [markdown]
# Buscar el inmueble con 2 mts de Área

# %%
inmuebles.loc[inmuebles.Area == 2]
# Out:
#              Tipo                            Descripcion  Habitaciones  Banos  \
# 8401  Apartamento  Apartamento en venta en San Cristobal             3      1
#
#       Area         Barrio      UPZ          Valor Moneda     Precio  \
# 8401     2  San Cristobal  Sosiego  $ 180.000.000      $  180000000
#
#       Precio_Millon
# 8401         180.00

# %% [markdown]
# Se analiza si los datos se consultan para corregirlos o si se dan de baja del dataset

# %% [markdown]
# Graficar, mientras mas bins menos detalle

# %%
inmuebles['Precio_Millon'].plot.hist(bins=50)
# Out:
# <Axes: ylabel='Frequency'>

# %%
inmuebles['Precio_Millon'].plot.hist(bins=1000)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# Pandas nos permite la manipulación y cambio en los datos pero hay recursos que nos permiten hacer gráficos. Seaborn basadas en Matplotlib.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #Lienzo donde definire mi gráfico
sns.histplot(data= inmuebles, x='Precio_Millon') # Colocare mi histograma
plt.show()

# %% [markdown]
# Puedo colocarle titulo (title)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #Lienzo donde definire mi gráfico
grafica = sns.histplot(data= inmuebles, x='Precio_Millon') # Colocare mi histograma
grafica.set_title('Distribución de valores de los inmuebles en Bógota')
plt.show()

# %% [markdown]
# Coloco el limite maximo de nuestra variable, y como se comporta en nuestro gráfico.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #Lienzo donde definire mi gráfico
grafica = sns.histplot(data= inmuebles, x='Precio_Millon') # Colocare mi histograma
grafica.set_title('Distribución de valores de los inmuebles en Bógota')
plt.xlim((50,1000))
plt.show()

# %% [markdown]
# Tambien podemos colocar la curva de densidad.
# La curva que más se ajusta a nuestra distribucion de datos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #Lienzo donde definire mi gráfico
grafica = sns.histplot(data= inmuebles, x='Precio_Millon', kde=True) # Colocare mi histograma
grafica.set_title('Distribución de valores de los inmuebles en Bógota')
plt.xlim((50,1000))
plt.show()

# %% [markdown]
# Si queremos exportar el gráfico.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #Lienzo donde definire mi gráfico
grafica = sns.histplot(data= inmuebles, x='Precio_Millon', kde=True) # Colocare mi histograma
grafica.set_title('Distribución de valores de los inmuebles en Bógota')
#plt.savefigure('/content/drive/MyDrive/Alura-Latam/Graficos/bogota.png',format='png')
plt.xlim((50,1000))
plt.show()

# %% [markdown]
# Puedo crear un cubo de datos y agregar valores al gráfico.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #Lienzo donde definire mi gráfico
grafica = sns.histplot(data= inmuebles, x='Precio_Millon', kde=True, hue='Tipo') # Colocare mi histograma
grafica.set_title('Distribución de valores de los inmuebles en Bógota')
plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/Alura-Latam/Graficos/bogota.png',format='png')
plt.show()

# %% [markdown]
# Puedo acercarme al gráfico (zoom) para visualizar mas datos.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #Lienzo donde definire mi gráfico
grafica = sns.histplot(data= inmuebles, x='Precio_Millon', kde=True, hue='Tipo') # Colocare mi histograma
grafica.set_title('Distribución de valores de los inmuebles en Bógota')
plt.xlim((50,1000))
plt.ylim((0, 100))
plt.savefig('/content/drive/MyDrive/Alura-Latam/Graficos/bogota.png',format='png')
plt.show()

# %% [markdown]
# Queremos encontrar un valor de plt.ylim que nos permita der la distribución de datos que no se ven.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8)) #Lienzo donde definire mi gráfico
grafica = sns.histplot(data= inmuebles, x='Precio_Millon', kde=True, hue='Tipo') # Colocare mi histograma
grafica.set_title('Distribución de valores de los inmuebles en Bógota')
plt.xlim((50,1000))
plt.ylim((0, 20))
plt.savefig('/content/drive/MyDrive/Alura-Latam/Graficos/bogota.png',format='png')
plt.show()

# %% [markdown]
# Desafios
# 1. Estudiar mejor el histograma de valores (letras, labels, etiquetas, conclusión: cómo esta el valor de la Finca con respecto aparteamanentos), seleccionar 3 tipos de inmuebles.
# 2. El precio del metro cuadrado por barrio, qué grafica representa mejor esta nueva varialble, realizar el gráfico.

# %% [markdown]
# Crearemos otra columna en nuestro dataset "Valor_m2_Millon"

# %%
inmuebles['Valor_m2_Millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
#
#    Banos  Area              Barrio                                 UPZ  \
# 0      2    70  Zona Noroccidental  CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla         KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado  CHAPINERO: Chicó Lago + El Refugio
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78

# %% [markdown]
# Metro cuadrado por barrio, agrupo y saco el promedio.
# Siempre que se hace una agrupación se debe utilizar una función de agregación.

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos   Area  Precio_Millon  Valor_m2_Millon
# Barrio
# Alameda                     3.00   2.00  97.00         580.00             5.98
# Alhambra                    3.00   2.94 190.41         752.35             4.33
# Andes Norte                 3.00   2.86 124.86         709.57             6.05
# Antonio Nariño              4.31   2.50 163.06         459.22             3.53
# Barrancas                   2.87   2.13  70.20         314.13             4.42
# ...                          ...    ...    ...            ...              ...
# Villa Maria                 4.69   3.69 207.15         402.85             2.04
# Villas De Granada           3.45   2.32  86.59         282.30             3.17
# Villemar                    2.94   2.06  76.89         303.83             3.99
# Zona Franca                 2.00   1.00  54.00         160.00             2.96
# Zona Noroccidental          3.17   2.51 135.79         620.81             4.62
#
# [149 rows x 5 columns]

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# Barrancas                     66.24
# ...                             ...
# Villa Maria                   26.58
# Villas De Granada             69.71
# Villemar                      71.81
# Zona Franca                    2.96
# Zona Noroccidental          4049.16
#
# [149 rows x 5 columns]

# %% [markdown]
# Creamos una columna 'valor_m2_barrio' y dividimos la suma del precio de millon sobre la suma del area calculado por barrio.

# %%
datos_barrio['valor_m2_barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_Millon  valor_m2_barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# Andes Norte                   42.35             5.68
# Antonio Nariño               169.47             2.82
# Barrancas                     66.24             4.47
# ...                             ...              ...
# Villa Maria                   26.58             1.94
# Villas De Granada             69.71             3.26
# Villemar                      71.81             3.95
# Zona Franca                    2.96             2.96
# Zona Noroccidental          4049.16             4.57
#
# [149 rows x 6 columns]

# %% [markdown]
# Colocaremos este valor promedio por barrio en una nueva columna en nuestro dataset generando un diccionario para luego mapearlo y pasarlo al dataset.

# %%
m2_barrio = dict(datos_barrio['valor_m2_barrio'])

# %% [markdown]
# M2 por millón de nuestro dataset pasaremos estos datos.

# %%
inmuebles['valor_m2_barrio'] = inmuebles['Barrio']
inmuebles['valor_m2_barrio'] = inmuebles['valor_m2_barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_Millon  \
# 0    $ 360.000.000      $   360000000         360.00             5.14
# 1    $ 670.000.000      $   670000000         670.00             3.94
# 2  $ 1.120.000.000      $  1120000000        1120.00             7.78
# 3    $ 890.000.000      $   890000000         890.00             5.78
# 4    $ 970.000.000      $   970000000         970.00             7.58
#
#    valor_m2_barrio
# 0             4.57
# 1             3.40
# 2             8.10
# 3             5.66
# 4             6.29

# %% [markdown]
# Vemos los Top 10 de barrios que tiene más propiedades.

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index
top_barrios
# Out:
# Index(['Usaquén', 'Zona Noroccidental', 'Bosa', 'Kennedy', 'Cedritos',
#        'Barrios Unidos', 'Engativa', 'Suba', 'Santa Barbara', 'Chapinero'],
#       dtype='object')

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  valor_m2_barrio
# 0               5.98             5.98
# 1              73.56             3.95
# 2              42.35             5.68
# 3             169.47             2.82
# 4              66.24             4.47
# ..               ...              ...
# 144            26.58             1.94
# 145            69.71             3.26
# 146            71.81             3.95
# 147             2.96             2.96
# 148          4049.16             4.57
#
# [149 rows x 7 columns]

# %% [markdown]
# Puedo realizar consultas a este dataset que acabo de crear

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_Millon  valor_m2_barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# 50           1795.71             2.89
# 63           2127.66             3.38
# 125          2701.88             5.85
# 132          2000.72             4.32
# 138          6334.04             5.66
# 148          4049.16             4.57

# %% [markdown]
# Buscamos el gráfico más adecuado para mostrar la información boxplot, usaremos Matplotlib y Seaborn

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x="Barrio",y="valor_m2_barrio", data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45) # En el eje X los valores los muestro en 45 grados

# %% [markdown]
# Estamos considerando a los barrios que tienen mas inmuebles a la venta y Santa Barbara es el barrio que tiene más valor en el precio del metro cuadrado. Hacemos la consulta (query) sobre inmuebles.

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Achicamos el rango de consulta menores a 15 millones para expandir el gráfico

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Valor_m2_Millon', data = inmuebles.query('Barrio in @top_barrios & Valor_m2_Millon < 15'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Podemos hacer el mismo boxplot con el Área

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Area', data = inmuebles.query('Barrio in @top_barrios & Area < 300'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Podemos hacer el mismo boxplot con el Precio por Millón

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Precio_Millon', data = inmuebles.query('Barrio in @top_barrios & Precio_Millon < 2000'))
ax.tick_params(axis='x', rotation=45)
plt.show()

# %% [markdown]
# Vamos a traer datos estadísticos de la ciudad de Bogotá, directamente del DANE y vamos a ver como estos datos nos ayudarían en inclusión de nuevas variables para el cálculo del precio de los inmuebles en la ciudad de Bogotá.
#
# Encuesta Multiproposito de Bogotá para obtener información socio-económica y de entorno urbano de los habitantes de Bogotá para la formulación, seguimiento y evaluación de las políticas distritales.
#
# https://microdatos.dane.gov.co/index.php/catalog/743

# %% [markdown]
# El municipio 11001 corresponde a Bogotá

# %%
datos_raw = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Identificación (Capítulo A).csv', sep=';' ,encoding='latin-1')
datos_raw.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0  3004346.00    11  11001      1           3.00         Santa Fe
# 1  3004347.00    11  11001      1          14.00     Los Mártires
# 2  3004348.00    11  11001      1           3.00         Santa Fe
# 3  3004349.00    11  11001      1           1.00          Usaquén
# 4  3004350.00    11  11001      1           1.00          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1          37.00                            Santa Isabel     11001162
# 2         814.00  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4         803.00   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# 1                            Santa Isabel  17,8555889419101
# 2  SANTA FE: Las Nieves + Sagrado Corazón  10,0286103658331
# 3   USAQUÉN: Country Club + Santa Bárbara  28,6502122142802
# 4   USAQUÉN: Country Club + Santa Bárbara  24,4684068319009

# %% [markdown]
# Vemos un detalle de datos_raw para ver e que tamaño está

# %%
datos_raw.shape # 106467 filas y 11 columnas
# Out:
# (106467, 11)

# %% [markdown]
# Seleccionamos solo municipio Bogota, se eliminaron del registro 19963. Municipios fuera de 11001.

# %%
datos_raw = datos_raw.loc[datos_raw.MPIO == 11001] # MPIO es int64 puedo corrobar el dato de la columna con data_raw.ingo()
datos_raw.shape
# Out:
# (86504, 11)

# %% [markdown]
# Traemos las demá tablas

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Datos de la vivenda y su entorno (Capítulo B).csv', sep=';' ,encoding='latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Condiciones habitacionales del hogar (Capítulo C).csv', sep=';' ,encoding='latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Composición del hogar y demografía (Capítulo E).csv', sep=';' ,encoding='latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Educación (Capitulo H).csv', sep=';' ,encoding='latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep=';' ,encoding='latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Fuerza de trabajo (Capítulo K).csv', sep=';' ,encoding='latin-1')
# Out:
# <ipython-input-74-5a7ee9a3e380>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Condiciones habitacionales del hogar (Capítulo C).csv', sep=';' ,encoding='latin-1')
# <ipython-input-74-5a7ee9a3e380>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Composición del hogar y demografía (Capítulo E).csv', sep=';' ,encoding='latin-1')
# <ipython-input-74-5a7ee9a3e380>:4: DtypeWarning: Columns (26,81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Educación (Capitulo H).csv', sep=';' ,encoding='latin-1')
# <ipython-input-74-5a7ee9a3e380>:5: DtypeWarning: Columns (114,117,122,126,164,166,168) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_l = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv', sep=';' ,encoding='latin-1')
# <ipython-input-74-5a7ee9a3e380>:6: DtypeWarning: Columns (27,58,60,62,64,66,104,114,120,124,126,129,131,133) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_k = pd.read_csv('/content/drive/MyDrive/Alura-Latam/Archivos de Datos/Fuerza de trabajo (Capítulo K).csv', sep=';' ,encoding='latin-1')

# %% [markdown]
# Juntaremos en una tabla todos los datos de nuestras tablas en una a traves de una función "merge" de Pandas. Se hará a traves del número de encuesta, que es el que lo relaciona. Debo correrlo una vez para que no siga sumando columnas.

# %%
datos_dane = pd.merge(datos_raw, datos_b, on='DIRECTORIO', how='left')

# %%
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane, datos_c, on="DIRECTORIO", how='left')

# %%
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane, datos_e, on="DIRECTORIO", how='left')
# Out:
# <ipython-input-79-cd63ceb0493b>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane, datos_e, on="DIRECTORIO", how='left')

# %%
datos_dane.shape
# Out:
# (238559, 281)

# %%
datos_dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 238559 entries, 0 to 238558
# Columns: 281 entries, DIRECTORIO to FEX_C_y
# dtypes: float64(140), int64(126), object(15)
# memory usage: 513.3+ MB

# %% [markdown]
# Desafio
# 1. Dar un vistaso a la base de datos Dane, entender las variables conceptualmente para entender mejor el contexto de esta base.
# 2. Organizar tu notebook para que tu proyecto quede mejor presentado.
